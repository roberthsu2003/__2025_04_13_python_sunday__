# %% [markdown]
# ### DataFrame,Series的陣列運算

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

np.random.seed(42)
scores = np.random.randint(50, 101,(50,5))
df1:DataFrame = pd.DataFrame(scores,
             index=[f'學號{i}' for i in range(1,51)],
             columns=["國文","英文","數學","歷史","生物"])
df1

# %%
#Series可以做陣列運算
df_sum = df1['國文'] + df1['英文'] + df1['數學'] + df1['歷史'] + df1['生物']
df_mean = df_sum / 5.0
df_mean

# %%
#df新增欄位
df1["總分"] = df_sum
df1["平均"] = df_mean
df1
# Out:
#        國文   英文   數學  歷史   生物   總分    平均
# 學號1    88   78   64  92   57  379  75.8
# 學號2    70   88   68  72   60  358  71.6
# 學號3    60   73   85  89   73  380  76.0
# 學號4    52   71   51  73   93  340  68.0
# 學號5    79   87   51  70   82  369  73.8
# 學號6    61   71   93  74   98  397  79.4
# 學號7    76   91   77  65   64  373  74.6
# 學號8    96  100   93  52   86  427  85.4
# 學號9   100   56   70  58   88  372  74.4
# 學號10   67   53   74  63   99  356  71.2
# 學號11   58   75   51  69   77  330  66.0
# 學號12   96   56   93  57   96  398  79.6
# 學號13   84   63   66  85   99  397  79.4
# 學號14   89   53   51  55   91  339  67.8
# 學號15   53   78   67  75   93  366  73.2
# 學號16   83   59   85  63   80  370  74.0
# 學號17   97   64   57  63   72  353  70.6
# 學號18   89   70   65  94   67  385  77.0
# 學號19   96   73   75  74   94  412  82.4
# 學號20   90   78   64  94   50  376  75.2
# 學號21   74   56   58  73   50  311  62.2
# 學號22   93   57   73  60  100  383  76.6
# 學號23   66   57   84  84   82  373  74.6
# 學號24   54   91   88  90   77  400  80.0
# 學號25   56   58   57  61   83  315  63.0
# 學號26   82   97   72  73   86  410  82.0
# 學號27   84   93   89  71   76  413  82.6
# 學號28   84   50   84  86   96  400  80.0
# 學號29   63   52   50  54   75  294  58.8
# 學號30   63   88   76  58   64  349  69.8
# 學號31   64   75   91  62  100  392  78.4
# 學號32   81   88   98  81   53  401  80.2
# 學號33   79   86   72  88   94  419  83.8
# 學號34   64   92   78  85   62  381  76.2
# 學號35   81   56  100  71   77  385  77.0
# 學號36   51   91   94  55   77  368  73.6
# 學號37   77   93   93  69   79  411  82.2
# 學號38   60   77   74  88   82  381  76.2
# 學號39   50   76   62  90   52  330  66.0
# 學號40   88   55   57  76   58  334  66.8
# 學號41   86   82  100  91   93  452  90.4
# 學號42   73   64   81  81   73  372  74.4
# 學號43   90   98   98  61   88  435  87.0
# 學號44   51   52   98  86   98  385  77.0
# 學號45   66   98   51  51   77  343  68.6
# 學號46   72   86   81  82   50  371  74.2
# 學號47   68   51   93  75   81  368  73.6
# 學號48   55   81   53  60   66  315  63.0
# 學號49   87   73   54  83   55  352  70.4
# 學號50   71   60   97  65   82  375  75.0
