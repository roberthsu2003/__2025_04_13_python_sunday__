# %%
#標準寫法
import matplotlib.pyplot as plt

# 1.製作figure
fig = plt.figure()

# 2.在1.的figure上製作一個axes
ax_1 = fig.add_subplot(1, 1, 1)

# 3.將圖的數據儲存在axes中
X = [0, 1, 2]
Y = [3, 4, 5]
ax_1.plot(X, Y)

# 4.顯示圖
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
X = [0, 3, 9]
Y = [3, 4, 5]
axes.plot(X,Y,color='green',marker='o',linestyle='dashed',linewidth=2,markersize=12)
plt.show()

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /opt/miniconda3/envs/sunday/lib/python3.10/site-packages (3.2)

# %%
import wget

wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(1, 3, 1)
axes2 = figure.add_subplot(1, 3, 2)
axes3 = figure.add_subplot(1, 3, 3)

axes1.set_title("圖表1")
axes2.set_title("圖表2")
axes3.set_title("圖表3")
plt.show()
# Out:
# /opt/miniconda3/envs/sunday/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22294 (\N{CJK UNIFIED IDEOGRAPH-5716}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/sunday/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34920 (\N{CJK UNIFIED IDEOGRAPH-8868}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
